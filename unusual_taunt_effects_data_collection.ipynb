# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from datetime import datetime

# %%
print("\nProgram is starting...", flush=True)
# Out:
# Program is starting...

# %%
bp_resp = requests.get("https://backpack.tf/developer/particles")
bp_soup = BeautifulSoup(bp_resp.content, "html.parser")

# %%
table = bp_soup.find("table", {"class":"table table-bordered particle-table"})

effect_to_id = {}

for row in table.find_all("tr"):
    
    line = row.text.replace("\n","").strip()

    loc_of_number = line.find('#')
    loc_of_end = line.find('94x94')

    if loc_of_number >= 0 and loc_of_end >= 0:
        number, name = line[loc_of_number:loc_of_end].strip().replace("#","").split(" ", 1)
    
        if int(number) >= 3000: # a taunt effect
            effect_to_id[name] = number

# %%
wiki_resp = requests.get("https://wiki.teamfortress.com/wiki/Unusual")
wiki_soup = BeautifulSoup(wiki_resp.content, "html.parser")

irrelevant_equip_regions = ["Weapon effects", "Cosmetic effects"]

update_to_generation = {
    'Scream Fortress VI': 'Halloween 2014',
    'Scream Fortress VIII': 'Halloween 2016',
    'Scream Fortress X': 'Halloween 2018',
    'Scream Fortress XI': 'Halloween 2019',
    'Scream Fortress XII': 'Halloween 2020',
    'Smissmas 2019': 'Smissmas 2019',
    'Smissmas 2020': 'Smissmas 2020',
    'Summer 2020 Pack': 'Summer 2020',
    'Love & War Update': 'Love & War',
}

gen_rarities = {
    'Halloween 2014': 'Limited',
    'Halloween 2016': 'Limited',
    'Halloween 2018': 'Limited',
    'Halloween 2019': 'Limited',
    'Halloween 2020': 'Limited',
    'Smissmas 2019': 'Limited',
    'Smissmas 2020': 'Limited',
    'Summer 2020': 'Limited',
    'Love & War': 'Common',
}

gen_release_dates = {
    'Halloween 2014': '2014-10-29',
    'Halloween 2016': '2016-10-21',
    'Halloween 2018': '2018-10-19',
    'Halloween 2019': '2019-10-10',
    'Halloween 2020': '2020-10-01',
    'Smissmas 2019': '2019-12-16',
    'Smissmas 2020': '2020-12-03',
    'Love & War': '2014-06-18',
}

gen_availability = {
    'Halloween 2014': ['No Longer Obtainable'],
    'Halloween 2016': ['No Longer Obtainable'],
    'Halloween 2018': ['No Longer Obtainable'],
    'Halloween 2019': ['No Longer Obtainable'],
    'Halloween 2020': ['No Longer Obtainable'],
    'Smissmas 2019': ['No Longer Obtainable'],
    'Smissmas 2020': ['No Longer Obtainable'],
    'Love & War': ['Unusualifier'],
}

partner_effects = {
    'Ghastly Ghosts' : ['Haunted Phantasm (green)'],
    'Haunted Phantasm' : ['Ghastly Ghosts (purple)'],
    'Infernal Flames' : ['Infernal Smoke (greeen)'],
    'Infernal Smoke' : ['Infernal Flames (purple)'],
    'Acidic Bubbles of Envy' : ['Flammable Bubbles of Attraction (orange)', 'Poisonous Bubbles of Regret (purple)'],
    'Flammable Bubbles of Attraction' : ['Acidic Bubbles of Envy (yellow)', 'Poisonous Bubbles of Regret (purple)'],
    'Poisonous Bubbles of Regret' : ['Flammable Bubbles of Attraction (orange)', 'Acidic Bubbles of Envy (yellow)'],
    'Ominous Night' : ['Spooky Night (black)'],
    'Spooky Night' : ['Ominous Night (green)'],
    'Accursed' : ['Bewitched (purple)', 'Enchanted (gold)'],
    'Bewitched' : ['Accursed (green)', 'Enchanted (gold)'],
    'Enchanted' : ['Bewitched (purple)', 'Accursed (green)'],
    'Eerie Lightning' : ['Jarate Shock (yellow)', 'Terrifying Thunder (blue)'],
    'Jarate Shock' : ['Eerie Lightning (purple)', 'Terrifying Thunder (blue)'],
    'Terrifying Thunder' : ['Jarate Shock (yellow)', 'Eerie Lightning (purple)'],
    'Arachnid Assault' : ['Creepy Crawlies (purple)', 'Toxic Terrors (green)'],
    'Creepy Crawlies' : ['Arachnid Assault (red)', 'Toxic Terrors (green)'],
    'Toxic Terrors' : ['Creepy Crawlies (purple)', 'Arachnid Assault (red)'],
    'Arcane Assistance' : ['Astral Presence (green-purple)', 'Spectral Escort (lime-orange)'],
    'Astral Presence' : ['Arcane Assistance (team colors)', 'Spectral Escort (lime-orange)'],
    'Spectral Escort' : ['Astral Presence (green-purple)', 'Arcane Assistance (team colors)'],
    'Emerald Allurement' : ['Pyrophoric Personality (orange)', 'Spellbound Aspect (purple)'],
    'Pyrophoric Personality' : ['Emerald Allurement (green)', 'Spellbound Aspect (purple)'],
    'Spellbound Aspect' : ['Pyrophoric Personality (orange)', 'Emerald Allurement (green)'],
    'Static Shock' : ['Veno Shock (purple)'],
    'Veno Shock' : ['Static Shock (gold)'],
    'Arctic Aurora' : ['Wintery Wisp (purple)'],
    'Wintery Wisp' : ['Arctic Aurora (blue)'],
    'Festive Spirit' : ['Magical Spirit (purple-orange)', 'Winter Spirit (blue)'],
    'Magical Spirit' : ['Festive Spirit (green-orange)', 'Winter Spirit (blue)'],
    'Winter Spirit' : ['Magical Spirit (purple-orange)', 'Festive Spirit (green-orange)'],
    'Apotheosis' : ['Ascension (purple)'],
    'Ascension' : ['Apotheosis (blue)'],
    'Delightful Star' : ['Frosted Star (blue)'],
    'Frosted Star' : ['Delightful Star (green)'],
    'Shimmering Lights' : ['Twinkling Lights (red-green-blue)'],
    'Twinkling Lights' : ['Shimmering Lights (blue-white-gold)'],
    'Midnight Whirlwind' : ['Silver Cyclone (grey)'],
    'Silver Cyclone' : ['Midnight Whirlwind (black)'],
}

# %%
def get_raw_data(tables):

    raw_data = []

    for table in tables:
        for row in table.find_all("tr"):
            split = row.text.strip().split("\n\n")
            for item in split:
                if "Horseless Headless Horsemann" in item:
                    return raw_data[2:]
                elif len(item) > 0:
                    raw_data.append(item)
    return raw_data[2:]

# %%
tables = wiki_soup.find_all("table")

raw_data = get_raw_data(tables)

effect_to_update = {}
release_updates = set({})

skip = False
current_gen = None

for item in raw_data:
    if item.startswith("Community Sparkle Unusual effects"):
        pass
    elif item.startswith("List of"):
        current_update = item[len("List of "):item.find("effects")].replace("Unusual", "").strip()                       
    elif item in irrelevant_equip_regions:
        skip = True
    elif item == "Taunt effects":
        skip = False
    elif skip == False and len(item) > 0:
        clean_item = item.replace("(RED)", "").replace("(BLU)", "").strip()
        effect_to_update[clean_item] = current_update 
        release_updates.add(current_update)

# %%
updates_lst = list(release_updates)

gens_data = []

for release_update in updates_lst:
    gen = None
    rarity = None
    release_date = None
    availability = None
    
    if release_update in update_to_generation:
        gen = update_to_generation[release_update]
    
    if gen in gen_rarities:
        rarity = gen_rarities[gen]
    
    if gen in gen_availability:
        availability = gen_availability[gen]
    
    if gen in gen_release_dates:
        release_date = gen_release_dates[gen]
        
    gens_data.append([gen, rarity, availability, release_date, release_update])

# %%
gens_df = pd.DataFrame(gens_data).rename(columns = {0: "effect_generation", 1: "rarity", 2: "availability", 3: "release_date", 4: "release_update"})
gens_df.set_index("effect_generation").to_csv("taunt_effect_generations.csv")

# %%
gens_df
# Out:
#   effect_generation   rarity            availability release_date  \
# 0    Halloween 2020  Limited  [No Longer Obtainable]   2020-10-01
# 1    Halloween 2019  Limited  [No Longer Obtainable]   2019-10-10
# 2     Smissmas 2019  Limited  [No Longer Obtainable]   2019-12-16
# 3    Halloween 2016  Limited  [No Longer Obtainable]   2016-10-21
# 4        Love & War   Common          [Unusualifier]   2014-06-18
# 5     Smissmas 2020  Limited  [No Longer Obtainable]   2020-12-03
# 6    Halloween 2014  Limited  [No Longer Obtainable]   2014-10-29
# 7    Halloween 2018  Limited  [No Longer Obtainable]   2018-10-19
#
#          release_update
# 0   Scream Fortress XII
# 1    Scream Fortress XI
# 2         Smissmas 2019
# 3  Scream Fortress VIII
# 4     Love & War Update
# 5         Smissmas 2020
# 6    Scream Fortress VI
# 7     Scream Fortress X

# %%
results = []

for effect, release_update in effect_to_update.items():
    
    effect_id = None
    partners = []
    
    if effect in effect_to_id:
        effect_id = effect_to_id[effect]
        
    if effect in partner_effects:
        partners = partner_effects[effect]
        
    if release_update in update_to_generation:
        gen = update_to_generation[release_update]
        
    results.append([effect, effect_id, gen, partners])

# %%
effects_df = pd.DataFrame(results).rename(columns = {0: "effect_name", 1: "effect_id", 2: "effect_generation", 3: "partner_effects"})

# %%
effects_df
# Out:
#                         effect_name effect_id effect_generation  \
# 0                    Ghastly Ghosts      3012    Halloween 2014
# 1                  Haunted Phantasm      3011    Halloween 2014
# 2                   Hellish Inferno      3013    Halloween 2016
# 3                   Infernal Flames      3015    Halloween 2016
# 4                    Infernal Smoke      3016    Halloween 2016
# 5                    Spectral Swirl      3014    Halloween 2016
# 6            Acidic Bubbles of Envy      3017    Halloween 2018
# 7   Flammable Bubbles of Attraction      3018    Halloween 2018
# 8                     Ominous Night      3022    Halloween 2018
# 9       Poisonous Bubbles of Regret      3019    Halloween 2018
# 10                  Roaring Rockets      3020    Halloween 2018
# 11                     Spooky Night      3021    Halloween 2018
# 12                         Accursed      3024    Halloween 2019
# 13                        Bewitched      3023    Halloween 2019
# 14                  Eerie Lightning      3027    Halloween 2019
# 15                        Enchanted      3025    Halloween 2019
# 16                     Jarate Shock      3029    Halloween 2019
# 17                      Nether Void      3030    Halloween 2019
# 18                      Static Mist      3026    Halloween 2019
# 19               Terrifying Thunder      3028    Halloween 2019
# 20                 Arachnid Assault      3047    Halloween 2020
# 21                Arcane Assistance      3040    Halloween 2020
# 22                  Astral Presence      3038    Halloween 2020
# 23                  Creepy Crawlies      3048    Halloween 2020
# 24               Emerald Allurement      3041    Halloween 2020
# 25           Pyrophoric Personality      3042    Halloween 2020
# 26                  Spectral Escort      3037    Halloween 2020
# 27                Spellbound Aspect      3043    Halloween 2020
# 28                     Static Shock      3044    Halloween 2020
# 29                    Toxic Terrors      3046    Halloween 2020
# 30                       Veno Shock      3045    Halloween 2020
# 31                    Arctic Aurora      3033     Smissmas 2019
# 32                   Festive Spirit      3035     Smissmas 2019
# 33             Good-Hearted Goodies      3031     Smissmas 2019
# 34                   Magical Spirit      3036     Smissmas 2019
# 35                    Winter Spirit      3034     Smissmas 2019
# 36                     Wintery Wisp      3032     Smissmas 2019
# 37                       Apotheosis      None     Smissmas 2020
# 38                        Ascension      None     Smissmas 2020
# 39                  Delightful Star      None     Smissmas 2020
# 40                     Frosted Star      None     Smissmas 2020
# 41            Reindoonicorn Rancher      None     Smissmas 2020
# 42                Shimmering Lights      None     Smissmas 2020
# 43                 Twinkling Lights      None     Smissmas 2020
# 44                              '72      3004        Love & War
# 45              Fountain of Delight      3005        Love & War
# 46                       Holy Grail      3003        Love & War
# 47                      Mega Strike      3010        Love & War
# 48               Midnight Whirlwind      3008        Love & War
# 49                  Screaming Tiger      3006        Love & War
# 50                      Showstopper      3002        Love & War
# 51                   Silver Cyclone      3009        Love & War
# 52               Skill Gotten Gains      3007        Love & War
#
#                                       partner_effects
# 0                          [Haunted Phantasm (green)]
# 1                           [Ghastly Ghosts (purple)]
# 2                                                  []
# 3                           [Infernal Smoke (greeen)]
# 4                          [Infernal Flames (purple)]
# 5                                                  []
# 6   [Flammable Bubbles of Attraction (orange), Poi...
# 7   [Acidic Bubbles of Envy (yellow), Poisonous Bu...
# 8                              [Spooky Night (black)]
# 9   [Flammable Bubbles of Attraction (orange), Aci...
# 10                                                 []
# 11                            [Ominous Night (green)]
# 12             [Bewitched (purple), Enchanted (gold)]
# 13               [Accursed (green), Enchanted (gold)]
# 14  [Jarate Shock (yellow), Terrifying Thunder (bl...
# 15             [Bewitched (purple), Accursed (green)]
# 16  [Eerie Lightning (purple), Terrifying Thunder ...
# 17                                                 []
# 18                                                 []
# 19  [Jarate Shock (yellow), Eerie Lightning (purple)]
# 20  [Creepy Crawlies (purple), Toxic Terrors (green)]
# 21  [Astral Presence (green-purple), Spectral Esco...
# 22  [Arcane Assistance (team colors), Spectral Esc...
# 23    [Arachnid Assault (red), Toxic Terrors (green)]
# 24  [Pyrophoric Personality (orange), Spellbound A...
# 25  [Emerald Allurement (green), Spellbound Aspect...
# 26  [Astral Presence (green-purple), Arcane Assist...
# 27  [Pyrophoric Personality (orange), Emerald Allu...
# 28                              [Veno Shock (purple)]
# 29  [Creepy Crawlies (purple), Arachnid Assault (r...
# 30                              [Static Shock (gold)]
# 31                            [Wintery Wisp (purple)]
# 32  [Magical Spirit (purple-orange), Winter Spirit...
# 33                                                 []
# 34  [Festive Spirit (green-orange), Winter Spirit ...
# 35  [Magical Spirit (purple-orange), Festive Spiri...
# 36                             [Arctic Aurora (blue)]
# 37                               [Ascension (purple)]
# 38                                [Apotheosis (blue)]
# 39                              [Frosted Star (blue)]
# 40                          [Delightful Star (green)]
# 41                                                 []
# 42                [Twinkling Lights (red-green-blue)]
# 43              [Shimmering Lights (blue-white-gold)]
# 44                                                 []
# 45                                                 []
# 46                                                 []
# 47                                                 []
# 48                            [Silver Cyclone (grey)]
# 49                                                 []
# 50                                                 []
# 51                       [Midnight Whirlwind (black)]
# 52                                                 []

# %%
effects_df.set_index("effect_name").to_csv("taunt_effects.csv")

# %%
full_effects_df = effects_df.merge(gens_df,on= "effect_generation")

# %%
full_effects_df
# Out:
#                         effect_name effect_id effect_generation  \
# 0                    Ghastly Ghosts      3012    Halloween 2014
# 1                  Haunted Phantasm      3011    Halloween 2014
# 2                   Hellish Inferno      3013    Halloween 2016
# 3                   Infernal Flames      3015    Halloween 2016
# 4                    Infernal Smoke      3016    Halloween 2016
# 5                    Spectral Swirl      3014    Halloween 2016
# 6            Acidic Bubbles of Envy      3017    Halloween 2018
# 7   Flammable Bubbles of Attraction      3018    Halloween 2018
# 8                     Ominous Night      3022    Halloween 2018
# 9       Poisonous Bubbles of Regret      3019    Halloween 2018
# 10                  Roaring Rockets      3020    Halloween 2018
# 11                     Spooky Night      3021    Halloween 2018
# 12                         Accursed      3024    Halloween 2019
# 13                        Bewitched      3023    Halloween 2019
# 14                  Eerie Lightning      3027    Halloween 2019
# 15                        Enchanted      3025    Halloween 2019
# 16                     Jarate Shock      3029    Halloween 2019
# 17                      Nether Void      3030    Halloween 2019
# 18                      Static Mist      3026    Halloween 2019
# 19               Terrifying Thunder      3028    Halloween 2019
# 20                 Arachnid Assault      3047    Halloween 2020
# 21                Arcane Assistance      3040    Halloween 2020
# 22                  Astral Presence      3038    Halloween 2020
# 23                  Creepy Crawlies      3048    Halloween 2020
# 24               Emerald Allurement      3041    Halloween 2020
# 25           Pyrophoric Personality      3042    Halloween 2020
# 26                  Spectral Escort      3037    Halloween 2020
# 27                Spellbound Aspect      3043    Halloween 2020
# 28                     Static Shock      3044    Halloween 2020
# 29                    Toxic Terrors      3046    Halloween 2020
# 30                       Veno Shock      3045    Halloween 2020
# 31                    Arctic Aurora      3033     Smissmas 2019
# 32                   Festive Spirit      3035     Smissmas 2019
# 33             Good-Hearted Goodies      3031     Smissmas 2019
# 34                   Magical Spirit      3036     Smissmas 2019
# 35                    Winter Spirit      3034     Smissmas 2019
# 36                     Wintery Wisp      3032     Smissmas 2019
# 37                       Apotheosis      None     Smissmas 2020
# 38                        Ascension      None     Smissmas 2020
# 39                  Delightful Star      None     Smissmas 2020
# 40                     Frosted Star      None     Smissmas 2020
# 41            Reindoonicorn Rancher      None     Smissmas 2020
# 42                Shimmering Lights      None     Smissmas 2020
# 43                 Twinkling Lights      None     Smissmas 2020
# 44                              '72      3004        Love & War
# 45              Fountain of Delight      3005        Love & War
# 46                       Holy Grail      3003        Love & War
# 47                      Mega Strike      3010        Love & War
# 48               Midnight Whirlwind      3008        Love & War
# 49                  Screaming Tiger      3006        Love & War
# 50                      Showstopper      3002        Love & War
# 51                   Silver Cyclone      3009        Love & War
# 52               Skill Gotten Gains      3007        Love & War
#
#                                       partner_effects   rarity  \
# 0                          [Haunted Phantasm (green)]  Limited
# 1                           [Ghastly Ghosts (purple)]  Limited
# 2                                                  []  Limited
# 3                           [Infernal Smoke (greeen)]  Limited
# 4                          [Infernal Flames (purple)]  Limited
# 5                                                  []  Limited
# 6   [Flammable Bubbles of Attraction (orange), Poi...  Limited
# 7   [Acidic Bubbles of Envy (yellow), Poisonous Bu...  Limited
# 8                              [Spooky Night (black)]  Limited
# 9   [Flammable Bubbles of Attraction (orange), Aci...  Limited
# 10                                                 []  Limited
# 11                            [Ominous Night (green)]  Limited
# 12             [Bewitched (purple), Enchanted (gold)]  Limited
# 13               [Accursed (green), Enchanted (gold)]  Limited
# 14  [Jarate Shock (yellow), Terrifying Thunder (bl...  Limited
# 15             [Bewitched (purple), Accursed (green)]  Limited
# 16  [Eerie Lightning (purple), Terrifying Thunder ...  Limited
# 17                                                 []  Limited
# 18                                                 []  Limited
# 19  [Jarate Shock (yellow), Eerie Lightning (purple)]  Limited
# 20  [Creepy Crawlies (purple), Toxic Terrors (green)]  Limited
# 21  [Astral Presence (green-purple), Spectral Esco...  Limited
# 22  [Arcane Assistance (team colors), Spectral Esc...  Limited
# 23    [Arachnid Assault (red), Toxic Terrors (green)]  Limited
# 24  [Pyrophoric Personality (orange), Spellbound A...  Limited
# 25  [Emerald Allurement (green), Spellbound Aspect...  Limited
# 26  [Astral Presence (green-purple), Arcane Assist...  Limited
# 27  [Pyrophoric Personality (orange), Emerald Allu...  Limited
# 28                              [Veno Shock (purple)]  Limited
# 29  [Creepy Crawlies (purple), Arachnid Assault (r...  Limited
# 30                              [Static Shock (gold)]  Limited
# 31                            [Wintery Wisp (purple)]  Limited
# 32  [Magical Spirit (purple-orange), Winter Spirit...  Limited
# 33                                                 []  Limited
# 34  [Festive Spirit (green-orange), Winter Spirit ...  Limited
# 35  [Magical Spirit (purple-orange), Festive Spiri...  Limited
# 36                             [Arctic Aurora (blue)]  Limited
# 37                               [Ascension (purple)]  Limited
# 38                                [Apotheosis (blue)]  Limited
# 39                              [Frosted Star (blue)]  Limited
# 40                          [Delightful Star (green)]  Limited
# 41                                                 []  Limited
# 42                [Twinkling Lights (red-green-blue)]  Limited
# 43              [Shimmering Lights (blue-white-gold)]  Limited
# 44                                                 []   Common
# 45                                                 []   Common
# 46                                                 []   Common
# 47                                                 []   Common
# 48                            [Silver Cyclone (grey)]   Common
# 49                                                 []   Common
# 50                                                 []   Common
# 51                       [Midnight Whirlwind (black)]   Common
# 52                                                 []   Common
#
#               availability release_date        release_update
# 0   [No Longer Obtainable]   2014-10-29    Scream Fortress VI
# 1   [No Longer Obtainable]   2014-10-29    Scream Fortress VI
# 2   [No Longer Obtainable]   2016-10-21  Scream Fortress VIII
# 3   [No Longer Obtainable]   2016-10-21  Scream Fortress VIII
# 4   [No Longer Obtainable]   2016-10-21  Scream Fortress VIII
# 5   [No Longer Obtainable]   2016-10-21  Scream Fortress VIII
# 6   [No Longer Obtainable]   2018-10-19     Scream Fortress X
# 7   [No Longer Obtainable]   2018-10-19     Scream Fortress X
# 8   [No Longer Obtainable]   2018-10-19     Scream Fortress X
# 9   [No Longer Obtainable]   2018-10-19     Scream Fortress X
# 10  [No Longer Obtainable]   2018-10-19     Scream Fortress X
# 11  [No Longer Obtainable]   2018-10-19     Scream Fortress X
# 12  [No Longer Obtainable]   2019-10-10    Scream Fortress XI
# 13  [No Longer Obtainable]   2019-10-10    Scream Fortress XI
# 14  [No Longer Obtainable]   2019-10-10    Scream Fortress XI
# 15  [No Longer Obtainable]   2019-10-10    Scream Fortress XI
# 16  [No Longer Obtainable]   2019-10-10    Scream Fortress XI
# 17  [No Longer Obtainable]   2019-10-10    Scream Fortress XI
# 18  [No Longer Obtainable]   2019-10-10    Scream Fortress XI
# 19  [No Longer Obtainable]   2019-10-10    Scream Fortress XI
# 20  [No Longer Obtainable]   2020-10-01   Scream Fortress XII
# 21  [No Longer Obtainable]   2020-10-01   Scream Fortress XII
# 22  [No Longer Obtainable]   2020-10-01   Scream Fortress XII
# 23  [No Longer Obtainable]   2020-10-01   Scream Fortress XII
# 24  [No Longer Obtainable]   2020-10-01   Scream Fortress XII
# 25  [No Longer Obtainable]   2020-10-01   Scream Fortress XII
# 26  [No Longer Obtainable]   2020-10-01   Scream Fortress XII
# 27  [No Longer Obtainable]   2020-10-01   Scream Fortress XII
# 28  [No Longer Obtainable]   2020-10-01   Scream Fortress XII
# 29  [No Longer Obtainable]   2020-10-01   Scream Fortress XII
# 30  [No Longer Obtainable]   2020-10-01   Scream Fortress XII
# 31  [No Longer Obtainable]   2019-12-16         Smissmas 2019
# 32  [No Longer Obtainable]   2019-12-16         Smissmas 2019
# 33  [No Longer Obtainable]   2019-12-16         Smissmas 2019
# 34  [No Longer Obtainable]   2019-12-16         Smissmas 2019
# 35  [No Longer Obtainable]   2019-12-16         Smissmas 2019
# 36  [No Longer Obtainable]   2019-12-16         Smissmas 2019
# 37  [No Longer Obtainable]   2020-12-03         Smissmas 2020
# 38  [No Longer Obtainable]   2020-12-03         Smissmas 2020
# 39  [No Longer Obtainable]   2020-12-03         Smissmas 2020
# 40  [No Longer Obtainable]   2020-12-03         Smissmas 2020
# 41  [No Longer Obtainable]   2020-12-03         Smissmas 2020
# 42  [No Longer Obtainable]   2020-12-03         Smissmas 2020
# 43  [No Longer Obtainable]   2020-12-03         Smissmas 2020
# 44          [Unusualifier]   2014-06-18     Love & War Update
# 45          [Unusualifier]   2014-06-18     Love & War Update
# 46          [Unusualifier]   2014-06-18     Love & War Update
# 47          [Unusualifier]   2014-06-18     Love & War Update
# 48          [Unusualifier]   2014-06-18     Love & War Update
# 49          [Unusualifier]   2014-06-18     Love & War Update
# 50          [Unusualifier]   2014-06-18     Love & War Update
# 51          [Unusualifier]   2014-06-18     Love & War Update
# 52          [Unusualifier]   2014-06-18     Love & War Update

# %%
full_effects_df.set_index("effect_name").to_csv("taunt_effects_full.csv")

# %%
print("Done!")
# Out:
# Done!
