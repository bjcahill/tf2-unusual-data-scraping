# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import time
from datetime import timedelta
from dateutil.parser import parse
import re

# %%
print("\nProgram is starting...", flush=True)
# Out:
# Program is starting...

# %%
resp = requests.get("https://wiki.teamfortress.com/wiki/Template:Unusual_quality_table")
soup = BeautifulSoup(resp.content, "html.parser")

tf_classes = ["Scout","Soldier","Pyro","Demoman","Heavy","Medic","Spy","Sniper","Engineer","All classes"]
irrelevant_equip_regions = ["Primary","Secondary","Cosmetic","Melee"]

# the wiki is not standard about this, so I am making the decision to call 
# these updates by their roman numeral name instead of by their 20XX name
standardized_halloween_updates = {
    "Scream Fortress 2013" : "Scream Fortress V",
    "Scream Fortress 2014" : "Scream Fortress VI",
    "Scream Fortress 2015" : "Scream Fortress VII",
    "Scream Fortress 2016" : "Scream Fortress VIII",
    "Scream Fortress 2017" : "Scream Fortress IX",
    "Scream Fortress 2018" : "Scream Fortress X",
    "Scream Fortress 2019" : "Scream Fortress XI",
    "Scream Fortress 2020" : "Scream Fortress XII"
}

# %%
tables = soup.find_all("table")
raw_data = []
for table in tables:
    for row in table.find_all("tr"):
        split = row.text.strip().split("\n\n")
        for item in split:
            raw_data.append(item)
raw_data = raw_data[1:-1]

# %%
item_names = set({})
skip = False

for item in raw_data:
    if item in tf_classes:
        pass
    elif item in irrelevant_equip_regions:
        skip = True
    elif item == "Taunt":
        skip = False
    elif skip == False and len(item) > 0:
        item_names.add(item.replace("\u200e",""))

# %%
def look_up_taunt(tables):
    
    tf_classes = []
    equip_region = None
    grade = None
    availability = ["Unusualifier"]
    release_date = None
    release_update = None
    
    for table in tables[:2]:
        for row in table.find_all("tr"):
            line = row.text.strip()
                                
            if line.startswith("Used by:"):
                lst = re.split(',',line[len("Worn by:"):])
                if "All classes" in lst:
                    tf_classes.append("All class")
                else:
                    for tf_class in lst:
                        tf_classes.append(tf_class.strip())
                                
            if "Grade" in line:
                temp = line.replace(item, "").replace("Taunt:","").replace("The\xa0", "").strip()
                grade = temp.split(" ")[0]
                        
            if line.startswith("Released:"):
                lst = line[len("Released:"):].split("(")
                if len(lst) == 2:
                    release_date = parse(lst[0].replace("Patch", "").strip()).strftime('%Y-%m-%d')
                    release_update = lst[1].strip().replace(")", "").replace("\u200e","")
                elif len(lst) == 1:
                    release_date = parse(lst[0].replace("Patch", "").strip()).strftime('%Y-%m-%d')
                    release_update = "Miscellaneous Minor Update"
                    
                if release_update in standardized_halloween_updates:
                    release_update = standardized_halloween_updates[release_update]
                    
            if line.startswith("Availability:"):
                lst = re.split(', |or ',line[len("Availability:"):])
                
                for source in lst:             
                    stripped = source.strip()
                    if stripped == "Uncrate (Unusual)":
                        availability.append("Mann Co. Audition Reel")
                        availability.append("Mann Co. Director's Cut Reel")
                                    
    return tf_classes, equip_region, grade, availability, release_update, release_date

# %%
item_names_list = list(item_names)
scraping_results = []
i = 0

start_time = time.time()

# This cell may take a few minutes to run. Sorry!
for item in item_names_list:
    
    if item == "Meet the Medic":
        to_search = "Meet_the_Medic_(taunt)" # Meet the Medic goes to the sfm short
    else:
        to_search = item
                        
    resp = requests.get("https://wiki.teamfortress.com/wiki/" + to_search)
    soup = BeautifulSoup(resp.content, "html.parser")

    tables = soup.find_all("table")
    
    tf_classes, equip_region, grade, availability, release_update, release_date = look_up_taunt(tables)
    
    if grade is None:
        grade = "No Grade"
                    
    scraping_results.append([item, tf_classes, grade, availability, 
                             release_date, release_update])
    time.sleep(0.1)
    i += 1
    print("Progress: " + str(int(round(i / len(item_names), 2) * 100)) + "% Time elapsed: " + str(timedelta(seconds=time.time() - start_time)), end='\r', flush=True)
# Out:
# Progress: 100% Time elapsed: 0:00:51.926807

# %%
results_df = pd.DataFrame(scraping_results).rename(columns= {0: "item_name", 1: "class", 2: "grade", 3: "availability", 4: "release_date",
                                                            5: "release_update"})

# %%
results_df
# Out:
#                 item_name        class     grade  \
# 0             Shred Alert  [All class]  No Grade
# 1             Victory Lap  [All class]  No Grade
# 2       Soldier's Requiem    [Soldier]  No Grade
# 3            Panzer Pants    [Soldier]  No Grade
# 4          Meet the Medic      [Medic]  No Grade
# 5            Burstchester  [All class]  Assassin
# 6    Proletariat Posedown      [Heavy]  No Grade
# 7       Boston Breakdance      [Scout]  No Grade
# 8           Luxury Lounge        [Spy]  No Grade
# 9             Most Wanted     [Sniper]  No Grade
# 10             Mannrobics  [All class]  No Grade
# 11    Second Rate Sorcery  [All class]  No Grade
# 12                Carlton      [Scout]  No Grade
# 13           Jumping Jack   [Engineer]  No Grade
# 14          Didgeridrongo     [Sniper]  No Grade
# 15                  Conga  [All class]  No Grade
# 16      Deep Fried Desire      [Scout]  No Grade
# 17             High Five!  [All class]  No Grade
# 18           Oblooterated    [Demoman]  No Grade
# 19            Disco Fever        [Spy]  No Grade
# 20             Buy A Life        [Spy]  No Grade
# 21       Skating Scorcher       [Pyro]  No Grade
# 22   Surgeon's Squeezebox      [Medic]  No Grade
# 23          Kazotsky Kick  [All class]  No Grade
# 24       Flippin' Awesome  [All class]  No Grade
# 25          Schadenfreude  [All class]  No Grade
# 26  Rock, Paper, Scissors        [All]  No Grade
# 27     Battin' a Thousand      [Scout]  No Grade
# 28      Russian Arms Race      [Heavy]  No Grade
# 29          Dueling Banjo   [Engineer]  No Grade
# 30        Balloonibouncer       [Pyro]  No Grade
# 31              I See You     [Sniper]  No Grade
# 32               Headcase       [Pyro]  No Grade
# 33         Results Are In      [Medic]  No Grade
# 34         Bucking Bronco   [Engineer]  No Grade
# 35   Fresh Brewed Victory    [Soldier]  No Grade
# 36           Square Dance  [All class]  No Grade
# 37               Box Trot        [Spy]  No Grade
# 38           Skullcracker  [All class]  No Grade
# 39             Pool Party       [Pyro]  No Grade
# 40   Trackman's Touchdown      [Scout]  No Grade
# 41              Bad Pipes    [Demoman]  No Grade
# 42       Soviet Strongarm      [Heavy]  No Grade
# 43            Killer Solo     [Sniper]  No Grade
# 44          Zoomin' Broom  [All class]  No Grade
# 45             Yeti Punch  [All class]  No Grade
# 46     Spent Well Spirits    [Demoman]  No Grade
# 47             Yeti Smash  [All class]  No Grade
# 48          Fubar Fanfare    [Soldier]  No Grade
# 49          Rancho Relaxo   [Engineer]  No Grade
# 50            Party Trick       [Pyro]  No Grade
# 51            Bunnyhopper      [Scout]  No Grade
# 52           Scooty Scoot      [Scout]  No Grade
# 53        Runner's Rhythm      [Scout]  No Grade
# 54    Scotsmann's Stagger    [Demoman]  No Grade
#
#                                          availability release_date  \
# 0                                      [Unusualifier]   2013-02-18
# 1                                      [Unusualifier]   2016-10-21
# 2                                      [Unusualifier]   2015-10-28
# 3                                      [Unusualifier]   2018-10-19
# 4   [Unusualifier, Mann Co. Audition Reel, Mann Co...   2011-06-23
# 5                                      [Unusualifier]   2015-10-06
# 6                                      [Unusualifier]   2015-07-02
# 7                                      [Unusualifier]   2015-03-12
# 8                                      [Unusualifier]   2017-12-21
# 9                                      [Unusualifier]   2015-03-12
# 10                                     [Unusualifier]   2015-12-17
# 11                                     [Unusualifier]   2016-10-21
# 12                                     [Unusualifier]   2016-07-07
# 13                                     [Unusualifier]   2017-10-20
# 14                                     [Unusualifier]   2016-12-21
# 15  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 16  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 17  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2011-10-13
# 18  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 19                                     [Unusualifier]   2016-07-07
# 20  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 21                                     [Unusualifier]   2017-12-21
# 22                                     [Unusualifier]   2017-12-21
# 23                                     [Unusualifier]   2015-07-02
# 24  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 25  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2011-06-23
# 26  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 27  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 28                                     [Unusualifier]   2017-10-20
# 29                                     [Unusualifier]   2017-10-20
# 30                                     [Unusualifier]   2016-07-07
# 31  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 32                                     [Unusualifier]   2017-10-20
# 33  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 34                                     [Unusualifier]   2015-12-17
# 35  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 36  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 37                                     [Unusualifier]   2015-07-02
# 38  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 39  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-12-08
# 40                                     [Unusualifier]   2017-12-21
# 41                                     [Unusualifier]   2015-12-17
# 42                                     [Unusualifier]   2017-10-20
# 43                                     [Unusualifier]   2015-03-12
# 44                                     [Unusualifier]   2015-10-28
# 45                                     [Unusualifier]   2017-10-20
# 46  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 47                                     [Unusualifier]   2017-10-20
# 48                                     [Unusualifier]   2016-07-07
# 49  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 50  [Unusualifier, Mann Co. Audition Reel, Mann Co...   2014-06-18
# 51                                     [Unusualifier]   2017-12-21
# 52                                     [Unusualifier]   2018-10-19
# 53                                     [Unusualifier]   2017-12-21
# 54                                     [Unusualifier]   2016-12-21
#
#                 release_update
# 0   Miscellaneous Minor Update
# 1         Scream Fortress VIII
# 2          Scream Fortress VII
# 3            Scream Fortress X
# 4                  Über Update
# 5    Invasion Community Update
# 6            Gun Mettle Update
# 7   Miscellaneous Minor Update
# 8                Smissmas 2017
# 9   Miscellaneous Minor Update
# 10          Tough Break Update
# 11        Scream Fortress VIII
# 12      Meet Your Match Update
# 13       Jungle Inferno Update
# 14               Smissmas 2016
# 15           Love & War Update
# 16           Love & War Update
# 17  Manniversary Update & Sale
# 18           Love & War Update
# 19      Meet Your Match Update
# 20           Love & War Update
# 21               Smissmas 2017
# 22               Smissmas 2017
# 23           Gun Mettle Update
# 24           Love & War Update
# 25                 Über Update
# 26           Love & War Update
# 27           Love & War Update
# 28       Jungle Inferno Update
# 29       Jungle Inferno Update
# 30      Meet Your Match Update
# 31           Love & War Update
# 32       Jungle Inferno Update
# 33           Love & War Update
# 34          Tough Break Update
# 35           Love & War Update
# 36           Love & War Update
# 37           Gun Mettle Update
# 38           Love & War Update
# 39      End of the Line Update
# 40               Smissmas 2017
# 41          Tough Break Update
# 42       Jungle Inferno Update
# 43  Miscellaneous Minor Update
# 44         Scream Fortress VII
# 45       Jungle Inferno Update
# 46           Love & War Update
# 47       Jungle Inferno Update
# 48      Meet Your Match Update
# 49           Love & War Update
# 50           Love & War Update
# 51               Smissmas 2017
# 52           Scream Fortress X
# 53               Smissmas 2017
# 54               Smissmas 2016

# %%
results_df.set_index("item_name").to_csv("taunts.csv")

# %%
print("\nDone!")
# Out:
# Done!
